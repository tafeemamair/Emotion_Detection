# %% [markdown]
# ## Emotion Detection

# %% [markdown]
# **Importing Libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

import tensorflow as tf
print("Tensorflow Version:", tf.__version__)
# Out:
# WARNING:tensorflow:From C:\Users\aisan\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Tensorflow Version: 2.15.0

# %% [markdown]
# **Exploring Dataset**

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing Data For Training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)
datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(inputs,64,(5,5))
    conv_3 = Convolution(inputs,128,(3,3))
    flatten = Flatten()(conv_3)
    dense_1 = Dense_f(flatten,256)
    output = Dense(7,activation = "softmax")(dense_1)
    model = Model(inputs = [inputs], outputs = [output])
    model.compile(loss = ['categorical_crossentropy'], optimizer = 'adam', metrics = ['accuracy'])
    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\aisan\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\aisan\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From C:\Users\aisan\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_2 (Conv2D)           (None, 48, 48, 128)       1280
#
#  batch_normalization_2 (Bat  (None, 48, 48, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 48, 48, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 24, 24, 128)       0
#
#  flatten (Flatten)           (None, 73728)             0
#
#  dense (Dense)               (None, 256)               18874624
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 18879239 (72.02 MB)
# Trainable params: 18878471 (72.02 MB)
# Non-trainable params: 768 (3.00 KB)
# _________________________________________________________________

# %% [markdown]
# **Initializing the Model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weight.h5", monitor = 'val_accuracy', save_weights_only = True, mode = 'max', verbose=1)
callbacks = [checkpoint]

# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\aisan\anaconda3\envs\emotion_detection_course\lib\site-packages (1.11.4)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in c:\users\aisan\appdata\roaming\python\python311\site-packages (from scipy) (1.26.2)

# %% [markdown]
# # Training The Model

# %%
import scipy

# %%
history = model.fit(
    x = train_generator,
    steps_per_epoch = steps_per_epoch,
    epochs = epochs,
    validation_data = validation_generator,
    validation_steps = validation_steps,
    callbacks = callbacks)
# Out:
# Epoch 1/15
# WARNING:tensorflow:From C:\Users\aisan\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\aisan\AppData\Roaming\Python\Python311\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 448/448 [==============================] - ETA: 0s - loss: 1.6407 - accuracy: 0.3795
# Epoch 1: saving model to model_weight.h5
# 448/448 [==============================] - 207s 458ms/step - loss: 1.6407 - accuracy: 0.3795 - val_loss: 1.5942 - val_accuracy: 0.3902
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3425 - accuracy: 0.4883
# Epoch 2: saving model to model_weight.h5
# 448/448 [==============================] - 241s 537ms/step - loss: 1.3425 - accuracy: 0.4883 - val_loss: 1.4796 - val_accuracy: 0.4289
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1834 - accuracy: 0.5590
# Epoch 3: saving model to model_weight.h5
# 448/448 [==============================] - 253s 566ms/step - loss: 1.1834 - accuracy: 0.5590 - val_loss: 1.5927 - val_accuracy: 0.3604
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0507 - accuracy: 0.6147
# Epoch 4: saving model to model_weight.h5
# 448/448 [==============================] - 230s 513ms/step - loss: 1.0507 - accuracy: 0.6147 - val_loss: 1.7255 - val_accuracy: 0.3655
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9189 - accuracy: 0.6628
# Epoch 5: saving model to model_weight.h5
# 448/448 [==============================] - 222s 495ms/step - loss: 0.9189 - accuracy: 0.6628 - val_loss: 1.7644 - val_accuracy: 0.3650
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8068 - accuracy: 0.7100
# Epoch 6: saving model to model_weight.h5
# 448/448 [==============================] - 212s 473ms/step - loss: 0.8068 - accuracy: 0.7100 - val_loss: 1.5494 - val_accuracy: 0.4549
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 0.6809 - accuracy: 0.7565
# Epoch 7: saving model to model_weight.h5
# 448/448 [==============================] - 197s 439ms/step - loss: 0.6809 - accuracy: 0.7565 - val_loss: 1.5403 - val_accuracy: 0.4735
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 0.5851 - accuracy: 0.7937
# Epoch 8: saving model to model_weight.h5
# 448/448 [==============================] - 198s 441ms/step - loss: 0.5851 - accuracy: 0.7937 - val_loss: 1.6271 - val_accuracy: 0.4773
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4979 - accuracy: 0.8266
# Epoch 9: saving model to model_weight.h5
# 448/448 [==============================] - 211s 470ms/step - loss: 0.4979 - accuracy: 0.8266 - val_loss: 1.6820 - val_accuracy: 0.4720
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.4346 - accuracy: 0.8509
# Epoch 10: saving model to model_weight.h5
# 448/448 [==============================] - 228s 509ms/step - loss: 0.4346 - accuracy: 0.8509 - val_loss: 1.7482 - val_accuracy: 0.4856
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3728 - accuracy: 0.8739
# Epoch 11: saving model to model_weight.h5
# 448/448 [==============================] - 226s 504ms/step - loss: 0.3728 - accuracy: 0.8739 - val_loss: 1.6979 - val_accuracy: 0.4895
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.3335 - accuracy: 0.8890
# Epoch 12: saving model to model_weight.h5
# 448/448 [==============================] - 258s 577ms/step - loss: 0.3335 - accuracy: 0.8890 - val_loss: 2.1123 - val_accuracy: 0.4513
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.9012
# Epoch 13: saving model to model_weight.h5
# 448/448 [==============================] - 241s 538ms/step - loss: 0.2960 - accuracy: 0.9012 - val_loss: 2.1943 - val_accuracy: 0.4446
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9117
# Epoch 14: saving model to model_weight.h5
# 448/448 [==============================] - 245s 546ms/step - loss: 0.2663 - accuracy: 0.9117 - val_loss: 1.9986 - val_accuracy: 0.4908
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9209
# Epoch 15: saving model to model_weight.h5
# 448/448 [==============================] - 248s 553ms/step - loss: 0.2429 - accuracy: 0.9209 - val_loss: 1.9512 - val_accuracy: 0.4973

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 9s 78ms/step - loss: 1.9509 - accuracy: 0.4974
# [1.950897455215454, 0.4973530173301697]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train', 'Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train', 'Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
